# %% [markdown]
# # Power Automate
# ___

# %% [markdown]
# The `Power Automate` home page offers you various options for creating your own flows and learning about the key features for `Power Automate`. You can get a quick sense of what's possible and how `Power Automate` can help your business.
#
# If your organization has `AI` enabled, then it also includes the new Copilot features.
#
# Learn more about [Power Automate](https://learn.microsoft.com/en-us/power-automate/getting-started).
#
#
# `Microsoft Power Automate` is a powerful automation tool that helps you automate repetitive and manual tasks in a user-friendly way. **Power Automate** is ideal for coders and non-coders alike, allowing you to create rule-based workflows and save time on routine tasks with an intuitive drag-and-drop interface. So, you can automate a wide range of tasks with Microsoft Power Automate, making it a powerful tool for businesses.
#
# `Power Automate` supports different apps and services such as Microsoft Office 365, Dropbox, Salesforce CRM , Google Drive, and more, making it a versatile tool for many industries and businesses. Plus, it integrates with other Microsoft products like SharePoint, Dynamics 365, Power BI and PowerApps so you can create more powerful and customized workflows, in a low-code way.

# %% [markdown]
# ## Power Automate send email based on form response
# ___
#
# ### Step 1: Create a Microsoft form.
# Click here to create a [Microsoft Form](https://github.com/microsoft/NTA/blob/main/Power%20Platform%20Samples/Microsoft%20Forms.ipynb)

# %% [markdown]
# ### Step 2: Create a flow in Microsoft Flow
#
# **1. To create a Flow, log in to `Power Automate`, then click on `Create` icon and select `Automated Cloud Flow`.**
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#  **2. Click skip**
#
# ![image-5.png](attachment:image-5.png)
#
# **3. Click on Add a trigger, then type `When a new response is submitted` and select it.**
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ### Step 3: When a new response is submitted
# ___
#
# **In this step, select the Form id from the dropdown list.**
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Step 4: Get response Details
# ___
#
# **This step will allow us to get and reference the incoming Form response. So, click on the Next step The plus sign and add an action). Then select Get response details action.**
#
# **Then Provide the Form id from the dropdown list and in Response id select the response id from the dynamic content.**
#
# ![image.png](attachment:image.png)
#
# **Then type `form` in the search bar and also choose Microsoft Form as shown below:**
# ![image-3.png](attachment:image-3.png)
#
# **Enter `Community volunteer registration form` in the Form Id, then click on fx to insert the Response id**.
# ![image-4.png](attachment:image-4.png)
#
# **Click on Dynamic Content, select List of response notification Response Id and click on Add.**
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ### Step 5: Send a feedback email to the to specific team
# ___
#
# **So to send a feedback email to the specific member of your team by supplying their email address.
#  click the Plus(+) sign and select outlook.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Click plus sign and chose an action**
#
# ![image-5.png](attachment:image-5.png)
#
#
# **Then click Sign in to authenticate into Outlook.com**
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# **Sign in and fill in the neccesary details. Add all the emails which is expected to recieve the form response. For the subject of the email click the Subject box and click on fx**
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### For the body of the Email: click on the body and click fx to format.
# ___
# ![image-10.png](attachment:image-10.png)
#
# ### Repeat this step for all the questions
# ___
# **Also insert all the 8 questions in the form to the body of the email and click on `fx` to add the respective functions
# Name - for example put the cursor infront of Name, click `fx` and click Dynamic content to choose name as the corresponding function as shown below:**
#
#
# **For the next question in the body put the cursor in front and click fx to add the corresponding function**
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
#
# **All done and click save**
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ### Test your Flow:
# ___
# **1. Fill and submit the form**
#  ![image.png](attachment:image.png)
#
#  **2. Check your flow in Power Automate: Go to make.powerautomate.com, click on flow, then click on the flow you created to view the detials.**
#  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Email Recieved After Form Submission
# ___
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Learn more about [Microsoft Power Automate](https://learn.microsoft.com/en-us/training/powerplatform/power-automate), create flow using [Copilot](https://learn.microsoft.com/en-us/power-automate/get-started-with-copilot), [Trigger a cloud flow from any Power BI report](https://learn.microsoft.com/en-us/power-automate/trigger-flow-powerbi-report), [Power Automate Training](https://learn.microsoft.com/en-us/training/paths/automate-process-power-automate/)
